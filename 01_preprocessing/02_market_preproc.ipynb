# %%
from glob import glob

import pandas as pd

# %%
# Market
glob("./../data/raw/market/*")
# Out:
# ['./../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20221231',
#  './../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930']

# %%
glob(
    "./../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/*"
)
# Out:
# ['./../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_인천_202209.csv',
#  './../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_전남_202209.csv',
#  './../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/[필독]파일열람방법.txt',
#  './../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경남_202209.csv',
#  './../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경북_202209.csv',
#  './../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_전북_202209.csv',
# ...

# %%
df = pd.read_csv(
    "./../data/raw/market/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_서울_202209.csv"
)

# %%
drop_columns = [col for col in df.columns if col.endswith("코드")] + [
    "대지구분코드",
    "대지구분명",
    "지번본번지",
    "지번부번지",
    "지번주소",
    "건물본번지",
    "건물부번지",
    "건물관리번호",
    "구우편번호",
    "신우편번호",
    "동정보",
    "층정보",
    "호정보",
]

# %%
df = df.drop(columns=drop_columns)

# %%
set(df["상권업종대분류명"])
# Out:
# {'관광/여가/오락', '부동산', '생활서비스', '소매', '숙박', '스포츠', '음식', '학문/교육'}

# %%
food_df = df[df["상권업종대분류명"] == "음식"]

# %%
food_df.to_csv("./../data/preproc/market/food_df.csv")
